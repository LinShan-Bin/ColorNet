# %%
import re
import jieba
import numpy as np
from gensim.models import KeyedVectors


from utils import ColorfulClothes

# %%
word2vec = KeyedVectors.load_word2vec_format('./merge_sgns_bigram_char300.txt', binary=False)

# %%
# Reference: https://blog.csdn.net/bailixuance/article/details/89555580
def find_chinese(file):
    pattern = re.compile(r'[^\u4e00-\u9fa5]')
    chinese = re.sub(pattern, '', file)
    return chinese

# %%
dataset = ColorfulClothes('./dataset/medium/', train=True)
dataset_test = ColorfulClothes('./dataset/medium/', train=False)


threshold = 0.45
color = '颜色'
redundancy = []
out_of_dict = []

def white_list(word):
    return '色' in word or '绿' in word or '青' in word or '黑' in word or '白' in word or '黄' in word

for images, labels in dataset:
    opt_tags = labels['optional_tags']
    for tags in opt_tags:
        tags = find_chinese(tags)
        words = jieba.lcut(tags, cut_all=True)
        for word in words:
            try:
                cov = word2vec.similarity(color, word)
                if cov < threshold and not white_list(word):
                    # redundancy.append(word + 'in' + tags)
                    redundancy.append(word)
            except:
                out_of_dict.append(word)


for images, labels in dataset_test:
    opt_tags = labels['optional_tags']
    for tags in opt_tags:
        tags = find_chinese(tags)
        words = jieba.lcut(tags, cut_all=True)
        for word in words:
            try:
                cov = word2vec.similarity(color, word)
                if cov < threshold and not white_list(word):
                    # redundancy.append(word + 'in' + tags)
                    redundancy.append(word)
            except:
                out_of_dict.append(word)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/0w/j3hd49492bncw4zlczqbyrmr0000gn/T/jieba.cache
# Loading model cost 0.313 seconds.
# Prefix dict has been built successfully.

# %%
redundancy = list(set(redundancy))
out_of_dict = list(set(out_of_dict))
print('Length of redundancy:', len(redundancy))
print('Length of out of dictionary:', len(out_of_dict))
# Out:
# Length of redundancy: 1955
# Length of out of dictionary: 48

# %%
np.save('redundancy.npy', redundancy)
np.save('out_of_dict.npy', out_of_dict)

# %%
word_test = '现货'
print(word_test in redundancy)
print(word2vec.similarity(word_test, '颜色'))

word_test2 = '牛油果'
print(word2vec.similarity(word_test2, '浅绿'))
# Out:
# True
# 0.24938019
# 0.29219952

# %%
print('Redundancy:\n', redundancy)
print('Out of dictionary:\n', out_of_dict)
# Out:
# Redundancy:
#  ['味儿', '单面', '抽象', '单条', '金鼓', '赤红', '熏烟', '磁铁', '不分', '越', '短', '天轮', '星辰', '凤尾', '明眼', '蒸汽', '蒂', '分', '均', '脚底', '小笨蛋', '蓬蓬', '香蕉', '猴子', '条', '芭比', '砖', '枚', '天内', '二件套', '支持', '沁', '烘焙', '袖长', '撞', '着', '金橘', '香芋', '蓟', '假', '衣领', '蕊', '染上', '批次', '蜜桔', '法国', '斜纹', '微', '锈', '元气', '瀑布', '喇叭裤', '欧洲', '大网', '裤装', '一见钟情', '雾霭', '贷', '三角', '涂鸦', '然', '加开', '袖', '风尚', '大利', '逸', '晕染', '底壳', '风衣', '兜', '克莱', '紫花', '奥兰', '小众', '单独', '砂', '丁香', '优先', '紫藤', '新', '思', '豆粉', '发货', '粗', '森', '浅', '酸奶', '叶子', '售罄', '子棉', '啡', '尼斯', '梦', '防晒', '门禁', '海红', '蛋', '单卡', '蔓', '个性', '建议', '记', '被', '带大', '栀子', '宝石', '漂', '透视', '琳', '琉', '边上', '玫', '汽车', '花篮', '泥金', '金盏花', '孤', '拼', '萌', '小姐', '两件套', '小鸭', '猪', '外强', '塞拉', '无货', '胸前', '花蕾', '汉服', '柑橘', '岩石', '今日', '柄', '退换', '棉质', '比', '赭石', '苔藓', '工装', '代尔', '衣', '丝', '头', '蝶粉', '文胸', '绣', '可可粉', '嫩草', '嫩肤', '薯', '缺货', '心花', '接连', '深空', '鱼鳞', '金盏', '组合', '烟草', '番茄', '无情', '胸针', '女红', '瑞', '兰花', '熏', '肤', '咸菜', '装酒', '吊带', '束', '子夜', '姐姐', '道奇', '域', '红粉', '茶', '豹纹', '卫', '鱼尾', '秋叶', '月光', '套', '欧', '光学', '英国', '钢圈', '丝米', '流行', '内', '月季', '椰奶', '拉米', '萨', '鲜', '有', '装', '双层', '芝麻', '一', '冰茶', '果粉', '霓', '抹胸', '呢', '梦想', '澳', '高端', '无码', '悠', '熊', '薄', '女人味', '涨价', '泡泡', '花粉', '米', '漆', '油桃', '光亮', '大气', '爵士', '浪漫', '薄荷', '糖果', '安静', '油灰', '火山灰', '瑞典', '芭蕾', '静夜', '单排', '进口', '升级', '豆沙', '原版', '规则', '玄', '背带裤', '桦', '巴', '木耳', '拍', '甲虫', '桖', '纤维', '没', '天河', '真爱', '马蓝', '兔', '金沙', '织毛衣', '铁锈', '雪松', '间', '魅力', '乌贼', '木', '左右', '松林', '花旗', '格外', '加里', '绣花', '驼毛', '面料', '关注', '花蜜', '腰果', '迷', '蝴蝶花', '秋香', '银边', '静谧', '满', '水洗', '饼干', '山茶', '高', '橘子', '雨', '人', '酒', '梨', '凉凉', '服', '银丝', '緑', '木槿', '职业', '浅水', '墨水', '洗手', '介意', '枫叶', '现', '芒', '优雅', '搬', '懒', '吊', '翻', '后发', '玉米', '爱心', '松', '极地', '兔子', '蘑菇', '月牙', '摩', '中华', '菊粉', '流沙', '恤', '式', '醉酒', '钢琴', '花红', '坠', '方领', '树莓', '防臭', '彩粉', '推荐', '叶', '内里', '混杂', '极光', '杏花', '毛头', '西装', '屑', '小草', '松兰', '核桃', '水牛', '灯芯', '黛', '宾利', '帆', '底水', '丹', '奢华', '自然', '小猪', '背带', '雾气', '新花', '俏丽', '富贵', '夏日', '浣', '梨花', '感', '奢', '宽松', '柠', '獐', '西裤', '果肉', '幽默', '丝光', '印第安', '几何', '睡裙', '山楂', '护士服', '宠', '方块', '天使', '脂粉', '爆', '桃花', '包括', '翻领', '极', '正', '印', '石', '香橙', '南瓜', '龙', '水粉', '神密', '明亮', '枯草', '勿', '文', '鱼', '蜜', '孕妇', '晒衣', '现货', '渲染', '魔力', '边长', '售完', '仅', '冷酷无情', '筒', '眼睛', '付款', '紅', '圣诞', '依', '假日', '边款', '蓝鲸', '凝', '二十', '皮', '高原', '狗狗', '殷红', '金', '红裙', '利', '领', '室外', '梅子', '小', '绳', '好', '紫堇', '牙粉', '超薄', '亮片', '加厚', '挞', '镶', '史', '针织', '马', '号', '哈根', '项链', '珠帘', '土灰', '直', '简', '枪', '优选', '工作日', '学院', '小脚', '富裕', '圭', '菱形', '忧郁', '橘子汁', '菠萝', '女上衣', '商品', '图', '千鸟', '迷彩', '水果', '蓬松', '腿短', '婷', '啤酒', '奇', '开衫', '朴', '春', '防走光', '酸', '典雅', '石墨', '烟熏', '美味', '莱', '合欢', '冰雪', '套红', '红格', '摩天轮', '裸', '肩上', '格套', '竹', '船', '瑟', '清爽', '金棕榈', '双', '草', '闪亮', '棕衣', '海盐', '肌肤', '绅士', '壳', '蓝花', '棉绒', '牛仔裙', '玫瑰', '雪梨', '罩衫', '不换', '圣诞树', '雅典', '寻', '裤长', '罗口', '红灯笼', '边', '心机', '单裤', '口袋', '配送', '万年', '真丝', '立体', '古朴', '带', '午夜', '洪', '太阳神', '放心', '亮', '有氧', '维尔', '徽章', '芝士', '瘦', '坎肩', '连衣裙', '外', '太阳', '搭', '臧', '汁', '小马', '浓烈', '收', '皱', '深', '空间', '圆形', '依旧', '耳朵', '西', '月', '冬季', '北极熊', '水仙', '扇', '奶酪', '毛边', '个子', '交叉', '攻', '经典', '露', '麻', '包含', '橙子', '砂石', '模特', '天空', '红毛', '数字', '蛋花', '台湾', '水', '喇', '陶土', '萝卜', '海藻', '日', '口', '少女', '皮皮', '红带', '同', '保暖', '光谱', '款', '笑脸', '夹克', '小狗', '购买', '机上', '珍', '不破', '玟', '茱萸', '谈', '花瓣', '天鹅', '炭灰', '网', '若', '衬衫', '不是', '奶', '魔法', '英伦', '内衬', '威尼斯', '卡', '水晶', '紫砂', '疏', '芯', '皇家', '正面', '双面', '彩花', '送', '尾花', '红蓝', '芭蕉', '后天', '赫本', '喇叭', '呢大衣', '挪威', '马甲', '龄', '反光', '红叶', '小猫', '扣子', '乌木', '麻纱', '标', '云雀', '小鸟', '乳浆', '半身裙', '不开', '花', '透明', '男蓝', '衣裤', '沙砾', '地衣', '芒果', '拍摄', '北', '桃子', '旅', '童话', '长袖', '红牡丹', '三文鱼', '大', '费', '醒目', '哈伦', '慎', '花鸟', '裙子', '夜空', '单宁', '街上', '透视装', '牡丹花', '风车', '粉', '侧边', '抹', '娃娃', '小粉', '女孩', '莎拉', '银亮', '红狐狸', '天蓝', '猪红', '女士', '红烧', '偏', '羽', '小红花', '冰河', '樱', '后', '旗袍', '摆', '送礼物', '恐龙', '断', '姐妹', '指纹', '好好', '红边', '女单', '迷雾', '烟火', '向阳花', ' ...
# Out of dictionary:
#  ['五天', '红白', '姜饼', '三号', '三粒', '白衬衫', '左右发', '秋香绿', '浅紫色', '粉腊', '六叶', '三分', '小姐姐', '二十发', '三件', '四号', '十发', '一号', '丹红色', '小玫瑰', '黄棕色', '九分', '蓝紫色', '一码', '黄衣黄', '夜来', '二件', '小黑裙', '一套', '白衬衣', '三文', '碧蓝色', '小黑猫', '雾灰色', '千丝', '单层', '两件', '八分', '五号', '二号', '两粒', '七分', '一条', '不支', '七日', '蕠', '艾草', '蓝黑色']
